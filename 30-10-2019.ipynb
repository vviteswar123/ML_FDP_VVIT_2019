# %%
import pandas as pd
pd.__version__
# Out:
# '0.25.1'

# %%
pd.Series([23,45,7,14])
# Out:
# 0    23
# 1    45
# 2     7
# 3    14
# dtype: int64

# %%
import numpy as np
np.array([23,45,7,14])
# Out:
# array([23, 45,  7, 14])

# %%
s=pd.Series([1,2,3],['one','two','three'])
s[0]
# Out:
# 1

# %%
s['one']
# Out:
# 1

# %%
# to display dates in a range
pd.date_range('2019-10-11',periods=5)
# Out:
# DatetimeIndex(['2019-10-11', '2019-10-12', '2019-10-13', '2019-10-14',
#                '2019-10-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
# to display dates in a range
pd.date_range('2019-10-11','2019-10-14')
# Out:
# DatetimeIndex(['2019-10-11', '2019-10-12', '2019-10-13', '2019-10-14'], dtype='datetime64[ns]', freq='D')

# %%
#to display tmperatures on different dates
temp=pd.Series([25,28,32,30],pd.date_range('2019-10-11','2019-10-14'))
temp
# Out:
# 2019-10-11    25
# 2019-10-12    28
# 2019-10-13    32
# 2019-10-14    30
# Freq: D, dtype: int64

# %%
# creating series from a dictionary
d={'hari':35,'giri':50,'suri':40}
sd=pd.Series(d)
sd
# Out:
# hari    35
# giri    50
# suri    40
# dtype: int64

# %%
# Creating dataframe from a dictionary
d={'name':['hari','giri','raj'],'marks':[65,75,55],'grade':['C','A','B']}
pd.DataFrame(d)
# Out:
#    name  marks grade
# 0  hari     65     C
# 1  giri     75     A
# 2   raj     55     B

# %%
# creating dataframe from an array
a_2d=np.array([['hari',65,'C'],['giri',75,'A'],['suri',55,'B']])
pd.DataFrame(a_2d)
# Out:
#       0   1  2
# 0  hari  65  C
# 1  giri  75  A
# 2  suri  55  B

# %%
pd.DataFrame(a_2d,columns=['name','marks','grade'])
# Out:
#    name marks grade
# 0  hari    65     C
# 1  giri    75     A
# 2  suri    55     B

# %%
# creating dataframe from a csv or tsv file
df=pd.read_csv('marks.csv')
df
# Out:
#    name  marks grade
# 0  hari     65     B
# 1  giri     75     A
# 2  suri     55     C

# %%
df=pd.read_csv('marks.tsv')
df
# Out:
#   name\tmarks\tgrade
# 0        hari\t65\tB
# 1        giri\t75\tA
# 2        suri\t55\tC

# %%
df=pd.read_csv('marks.tsv',sep='\t')
df
# Out:
#    name  marks grade
# 0  hari     65     B
# 1  giri     75     A
# 2  suri     55     C

# %%
path='https://raw.githubusercontent.com/vviteswar123/ML_FDP_VVIT_2019/master/global_sales_data/market_fact.csv'
data=pd.read_csv(path)
data.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
data.head(3)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59

# %%
data.sample(3)
# Out:
#         Ord_id Prod_id   Ship_id   Cust_id     Sales  Discount  \
# 5904  Ord_2787  Prod_3  SHP_3830  Cust_544   233.010      0.04
# 441    Ord_667  Prod_1   SHP_913  Cust_211  7036.110      0.00
# 7734  Ord_1331  Prod_4  SHP_1832  Cust_486  3821.039      0.05
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 5904              17    88.88           1.49                 0.35
# 441               43  1268.65          19.99                 0.66
# 7734              38  1057.89           5.99                 0.57

# %%
data.sample(3)
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 5247   Ord_984  Prod_2  SHP_1358   Cust_361   154.85      0.05
# 1296   Ord_210  Prod_8   SHP_287    Cust_94   242.36      0.08
# 4794  Ord_4923  Prod_1  SHP_6867  Cust_1681  1438.33      0.08
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 5247              38 -136.55           5.13                 0.59
# 1296               4 -131.48           1.99                 0.50
# 4794              43  163.38           8.22                 0.57

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
# to check for missing values
data.isnull()
# Out:
#       Ord_id  Prod_id  Ship_id  Cust_id  Sales  Discount  Order_Quantity  \
# 0      False    False    False    False  False     False           False
# 1      False    False    False    False  False     False           False
# 2      False    False    False    False  False     False           False
# 3      False    False    False    False  False     False           False
# 4      False    False    False    False  False     False           False
# ...      ...      ...      ...      ...    ...       ...             ...
# 8394   False    False    False    False  False     False           False
# 8395   False    False    False    False  False     False           False
# 8396   False    False    False    False  False     False           False
# 8397   False    False    False    False  False     False           False
# 8398   False    False    False    False  False     False           False
#
#       Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
data.isnull().sum()
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
data.dtypes
# Out:
# Ord_id                  object
# Prod_id                 object
# Ship_id                 object
# Cust_id                 object
# Sales                  float64
# Discount               float64
# Order_Quantity           int64
# Profit                 float64
# Shipping_Cost          float64
# Product_Base_Margin    float64
# dtype: object

# %%
# to know entire information about data frame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %%
data['Prod_id']
# Out:
# 0       Prod_16
# 1       Prod_13
# 2        Prod_4
# 3        Prod_6
# 4       Prod_17
#          ...
# 8394     Prod_4
# 8395     Prod_6
# 8396     Prod_6
# 8397    Prod_15
# 8398     Prod_6
# Name: Prod_id, Length: 8399, dtype: object

# %%
data.Prod_id
# Out:
# 0       Prod_16
# 1       Prod_13
# 2        Prod_4
# 3        Prod_6
# 4       Prod_17
#          ...
# 8394     Prod_4
# 8395     Prod_6
# 8396     Prod_6
# 8397    Prod_15
# 8398     Prod_6
# Name: Prod_id, Length: 8399, dtype: object

# %%
data.mean()
# Out:
# Sales                  1775.878179
# Discount                  0.049671
# Order_Quantity           25.571735
# Profit                  181.184424
# Shipping_Cost            12.838557
# Product_Base_Margin       0.512513
# dtype: float64

# %%
data.min()
# Out:
# Ord_id                   Ord_1
# Prod_id                 Prod_1
# Ship_id                  SHP_1
# Cust_id                 Cust_1
# Sales                     2.24
# Discount                     0
# Order_Quantity               1
# Profit                -14140.7
# Shipping_Cost             0.49
# Product_Base_Margin       0.35
# dtype: object

# %%
data.max()
# Out:
# Ord_id                  Ord_999
# Prod_id                  Prod_9
# Ship_id                 SHP_999
# Cust_id                Cust_999
# Sales                   89061.1
# Discount                   0.25
# Order_Quantity               50
# Profit                  27220.7
# Shipping_Cost            164.73
# Product_Base_Margin        0.85
# dtype: object

# %%
data.count()
# Out:
# Ord_id                 8399
# Prod_id                8399
# Ship_id                8399
# Cust_id                8399
# Sales                  8399
# Discount               8399
# Order_Quantity         8399
# Profit                 8399
# Shipping_Cost          8399
# Product_Base_Margin    8336
# dtype: int64

# %%
data.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
data.describe(include=object)
# Out:
#          Ord_id Prod_id   Ship_id    Cust_id
# count      8399    8399      8399       8399
# unique     5506      17      7701       1832
# top     Ord_542  Prod_6  SHP_5602  Cust_1140
# freq          6    1225         4         30

# %%
data.describe(include='all')
# Out:
#          Ord_id Prod_id   Ship_id    Cust_id         Sales     Discount  \
# count      8399    8399      8399       8399   8399.000000  8399.000000
# unique     5506      17      7701       1832           NaN          NaN
# top     Ord_542  Prod_6  SHP_5602  Cust_1140           NaN          NaN
# freq          6    1225         4         30           NaN          NaN
# mean        NaN     NaN       NaN        NaN   1775.878179     0.049671
# std         NaN     NaN       NaN        NaN   3585.050525     0.031823
# min         NaN     NaN       NaN        NaN      2.240000     0.000000
# 25%         NaN     NaN       NaN        NaN    143.195000     0.020000
# 50%         NaN     NaN       NaN        NaN    449.420000     0.050000
# 75%         NaN     NaN       NaN        NaN   1709.320000     0.080000
# max         NaN     NaN       NaN        NaN  89061.050000     0.250000
#
#         Order_Quantity        Profit  Shipping_Cost  Product_Base_Margin
# ...

# %%
data['Prod_id'].nunique()
# Out:
# 17

# %%
data['Prod_id'].value_counts()
# Out:
# Prod_6     1225
# Prod_3      915
# Prod_4      883
# Prod_5      788
# Prod_8      758
# Prod_13     633
# Prod_1      546
# Prod_2      434
# Prod_15     386
# Prod_11     361
# Prod_17     337
# Prod_12     288
# Prod_9      246
# Prod_10     189
# Prod_7      179
# Prod_16     144
# Prod_14      87
# Name: Prod_id, dtype: int64

# %%
data['Prod_id'].value_counts().index
# Out:
# Index(['Prod_6', 'Prod_3', 'Prod_4', 'Prod_5', 'Prod_8', 'Prod_13', 'Prod_1',
#        'Prod_2', 'Prod_15', 'Prod_11', 'Prod_17', 'Prod_12', 'Prod_9',
#        'Prod_10', 'Prod_7', 'Prod_16', 'Prod_14'],
#       dtype='object')

# %%
data['Sales']
# Out:
# 0        136.8100
# 1         42.2700
# 2       4701.6900
# 3       2337.8900
# 4       4233.1500
#           ...
# 8394    2841.4395
# 8395     127.1600
# 8396     243.0500
# 8397    3872.8700
# 8398     603.6900
# Name: Sales, Length: 8399, dtype: float64

# %%
data[['Sales']]
# Out:
#           Sales
# 0      136.8100
# 1       42.2700
# 2     4701.6900
# 3     2337.8900
# 4     4233.1500
# ...         ...
# 8394  2841.4395
# 8395   127.1600
# 8396   243.0500
# 8397  3872.8700
# 8398   603.6900
#
# [8399 rows x 1 columns]

# %%
data[['Sales','Discount']]
# Out:
#           Sales  Discount
# 0      136.8100      0.01
# 1       42.2700      0.01
# 2     4701.6900      0.00
# 3     2337.8900      0.09
# 4     4233.1500      0.08
# ...         ...       ...
# 8394  2841.4395      0.08
# 8395   127.1600      0.10
# 8396   243.0500      0.02
# 8397  3872.8700      0.03
# 8398   603.6900      0.00
#
# [8399 rows x 2 columns]

# %%
# to access rows 
data.loc[:,['Sales','Profit']]
# Out:
#           Sales   Profit
# 0      136.8100   -30.51
# 1       42.2700     4.56
# 2     4701.6900  1148.90
# 3     2337.8900   729.34
# 4     4233.1500  1219.87
# ...         ...      ...
# 8394  2841.4395   374.63
# 8395   127.1600   -74.03
# 8396   243.0500   -70.85
# 8397  3872.8700   565.34
# 8398   603.6900   131.39
#
# [8399 rows x 2 columns]

# %%
data.loc[0:5,['Sales','Profit']]
# Out:
#      Sales   Profit
# 0   136.81   -30.51
# 1    42.27     4.56
# 2  4701.69  1148.90
# 3  2337.89   729.34
# 4  4233.15  1219.87
# 5   164.02   -47.64

# %%
data.loc[0:5,'Sales':'Profit']
# Out:
#      Sales  Discount  Order_Quantity   Profit
# 0   136.81      0.01              23   -30.51
# 1    42.27      0.01              13     4.56
# 2  4701.69      0.00              26  1148.90
# 3  2337.89      0.09              43   729.34
# 4  4233.15      0.08              35  1219.87
# 5   164.02      0.03              23   -47.64

# %%
data.loc[0:5:2,'Sales':'Profit']
# Out:
#      Sales  Discount  Order_Quantity   Profit
# 0   136.81      0.01              23   -30.51
# 2  4701.69      0.00              26  1148.90
# 4  4233.15      0.08              35  1219.87

# %%
data.iloc[0:6,0:3]
# Out:
#      Ord_id  Prod_id   Ship_id
# 0  Ord_5446  Prod_16  SHP_7609
# 1  Ord_5406  Prod_13  SHP_7549
# 2  Ord_5446   Prod_4  SHP_7610
# 3  Ord_5456   Prod_6  SHP_7625
# 4  Ord_5485  Prod_17  SHP_7664
# 5  Ord_5446   Prod_6  SHP_7608

# %%
data.iloc[3:8]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3              43   729.34          14.30                 0.37
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55

# %%
data.loc[3:8]
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# 5  Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 6    Ord_31  Prod_12    SHP_41    Cust_26    14.7600      0.01
# 7  Ord_4725   Prod_4  SHP_6593  Cust_1641  3410.1575      0.10
# 8  Ord_4725  Prod_13  SHP_6593  Cust_1641   162.0000      0.01
#
#    Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3              43   729.34          14.30                 0.37
# 4              35  1219.87          26.30                 0.38
# 5              23   -47.64           6.15                 0.37
# 6               5     1.32           0.50                 0.36
# 7              48  1137.91           0.99                 0.55
# 8              33    45.84           0.71                 0.52

# %%
data['Sales'][data['Sales']>20000]
# Out:
# 84      21366.51
# 197     23106.46
# 385     28359.40
# 734     21320.58
# 798     20596.58
#           ...
# 7318    27875.54
# 7547    29345.27
# 7706    22079.47
# 8046    27663.92
# 8217    28389.14
# Name: Sales, Length: 66, dtype: float64

# %%
data.dtypes==object
# Out:
# Ord_id                  True
# Prod_id                 True
# Ship_id                 True
# Cust_id                 True
# Sales                  False
# Discount               False
# Order_Quantity         False
# Profit                 False
# Shipping_Cost          False
# Product_Base_Margin    False
# dtype: bool

# %%
data.columns[data.dtypes==object]
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id'], dtype='object')

# %%
data.columns[(data.dtypes=='float64') & (data.dtypes=='object')]
# Out:
# Index([], dtype='object')

# %%
i=data.Sales[(data['Sales']>20000) & (data['Sales']<50000)].index
data.loc[i,:]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 84    Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.51      0.00
# 197   Ord_2753   Prod_3  SHP_3778   Cust_997  23106.46      0.08
# 385   Ord_3707  Prod_17  SHP_5136  Cust_1307  28359.40      0.05
# 734   Ord_4705  Prod_17  SHP_6566  Cust_1592  21320.58      0.09
# 798   Ord_2477  Prod_11  SHP_3394   Cust_939  20596.58      0.09
# ...        ...      ...       ...        ...       ...       ...
# 7318   Ord_546  Prod_14   SHP_858   Cust_198  27875.54      0.00
# 7547  Ord_3170  Prod_10  SHP_4400  Cust_1162  29345.27      0.03
# 7706    Ord_79  Prod_17   SHP_105    Cust_42  22079.47      0.06
# 8046   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8217  Ord_3359  Prod_10  SHP_7245  Cust_1762  28389.14      0.07
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 84                 3 -11984.40          24.49                 0.39
# ...

# %%
data[data.Prod_id=='Prod_6']
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 3     Ord_5456  Prod_6  SHP_7625  Cust_1818  2337.89      0.09
# 5     Ord_5446  Prod_6  SHP_7608  Cust_1818   164.02      0.03
# 9     Ord_4725  Prod_6  SHP_6593  Cust_1641    57.22      0.07
# 11    Ord_1925  Prod_6  SHP_2637   Cust_708   465.90      0.05
# 18    Ord_4427  Prod_6  SHP_6171  Cust_1521   283.13      0.08
# ...        ...     ...       ...        ...      ...       ...
# 8368  Ord_3574  Prod_6  SHP_4947  Cust_1274   438.66      0.01
# 8380  Ord_2772  Prod_6  SHP_3807  Cust_1006   308.92      0.04
# 8395  Ord_5411  Prod_6  SHP_7555  Cust_1798   127.16      0.10
# 8396  Ord_5388  Prod_6  SHP_7524  Cust_1798   243.05      0.02
# 8398  Ord_5459  Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 3                 43  729.34          14.30                 0.37
# 5                 23  -47.64           6.15                 0.37
# ...

# %%
data[data.Product_Base_Margin.isnull()]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 107    Ord_250  Prod_15   SHP_346    Cust_45   8901.78      0.04
# 276   Ord_4770   Prod_1  SHP_6654  Cust_1652   1128.03      0.01
# 376   Ord_4076   Prod_1  SHP_5683  Cust_1384    740.49      0.10
# 584   Ord_2897  Prod_15  SHP_3998  Cust_1052    897.42      0.08
# 777   Ord_5142  Prod_15  SHP_7183  Cust_1746  10656.26      0.06
# ...        ...      ...       ...        ...       ...       ...
# 7657  Ord_3306  Prod_11  SHP_4586  Cust_1181   9601.94      0.08
# 8022  Ord_2174  Prod_15  SHP_2963   Cust_818   6131.54      0.06
# 8042  Ord_5357  Prod_11  SHP_7483  Cust_1803  14451.75      0.01
# 8367  Ord_3593  Prod_15  SHP_4975  Cust_1274   6685.05      0.09
# 8388  Ord_4424   Prod_1  SHP_6165  Cust_1519    994.04      0.03
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 107               31  2795.36          24.49                  NaN
# ...

# %%
data['New']=10

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'New'],
#       dtype='object')

# %%
data.drop('New',axis=1)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'New'],
#       dtype='object')

# %%
data.drop('New',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
data1=data.dropna()

# %%
print(data.shape)
print(data1.shape)
# Out:
# (8399, 10)
# (8336, 10)

# %%
data2=data.dropna(axis=1)

# %%
print(data.shape)
print(data2.shape)
# Out:
# (8399, 10)
# (8399, 9)

# %%
m=data.Product_Base_Margin.mean()
data.Product_Base_Margin.fillna(m)
# Out:
# 0       0.56
# 1       0.54
# 2       0.59
# 3       0.37
# 4       0.38
#         ...
# 8394    0.59
# 8395    0.37
# 8396    0.40
# 8397    0.62
# 8398    0.38
# Name: Product_Base_Margin, Length: 8399, dtype: float64

# %%
data.Product_Base_Margin.isnull().sum()
# Out:
# 63

# %%
m=data.Product_Base_Margin.mean()
data.Product_Base_Margin=data.Product_Base_Margin.fillna(m)

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
path='https://raw.githubusercontent.com/vviteswar123/ML_FDP_VVIT_2019/master/global_sales_data/cust_dimen.csv'
d1=pd.read_csv(path)

# %%
d1
# Out:
#       Order_ID  Order_Date Order_Priority    Ord_id
# 0            3  13-10-2010            LOW     Ord_1
# 1          293  01-10-2012           HIGH     Ord_2
# 2          483  10-07-2011           HIGH     Ord_3
# 3          515  28-08-2010  NOT SPECIFIED     Ord_4
# 4          613  17-06-2011           HIGH     Ord_5
# ...        ...         ...            ...       ...
# 5501     47360  08-10-2010  NOT SPECIFIED  Ord_5502
# 5502     52706  09-07-2012            LOW  Ord_5503
# 5503     54279  30-07-2011           HIGH  Ord_5504
# 5504     55558  09-08-2010         MEDIUM  Ord_5505
# 5505     56581  08-02-2009           HIGH  Ord_5506
#
# [5506 rows x 4 columns]

# %%
d1.isnull().sum().sum()
# Out:
# 0

# %%
d={'name':['a','b','c','d','e'],'marks':[50,40,30,None,None]}
d1=pd.DataFrame(d)
d1
# Out:
#   name  marks
# 0    a   50.0
# 1    b   40.0
# 2    c   30.0
# 3    d    NaN
# 4    e    NaN

# %%
d1.isnull().columns
# Out:
# Index(['name', 'marks'], dtype='object')

# %%
m=d1['marks'].mean()
m
# Out:
# 40.0

# %%
d1.marks=d1.marks.fillna(m)

# %%
d1
# Out:
#   name  marks
# 0    a   50.0
# 1    b   40.0
# 2    c   30.0
# 3    d   40.0
# 4    e   40.0

# %%
d1.isnull().sum()
# Out:
# name     0
# marks    0
# dtype: int64

# %%
# sorting data frame by value
data.sort_values(by='Sales')
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# ...        ...      ...       ...        ...       ...       ...
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 6700               1     -1.97           0.70                 0.37
# ...

# %%
data.sort_values(by='Sales',ascending=False)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# ...        ...      ...       ...        ...       ...       ...
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 2738              13  27220.69          24.49                 0.39
# ...

# %%
data.set_index('Ord_id')
# Out:
#           Prod_id   Ship_id    Cust_id      Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01              23
# Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01              13
# Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00              26
# Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09              43
# Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08              35
# ...           ...       ...        ...        ...       ...             ...
# Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08              28
# Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10              20
# Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02              39
# Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03              23
# Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00              47
#
# ...

# %%
data_ord=data.set_index('Ord_id')
data_ord.index
# Out:
# Index(['Ord_5446', 'Ord_5406', 'Ord_5446', 'Ord_5456', 'Ord_5485', 'Ord_5446',
#        'Ord_31', 'Ord_4725', 'Ord_4725', 'Ord_4725',
#        ...
#        'Ord_4444', 'Ord_5435', 'Ord_5435', 'Ord_5384', 'Ord_5348', 'Ord_5353',
#        'Ord_5411', 'Ord_5388', 'Ord_5348', 'Ord_5459'],
#       dtype='object', name='Ord_id', length=8399)

# %%
# sorting data in dataframe using index
data_ord.sort_index()
# Out:
#           Prod_id   Ship_id   Cust_id     Sales  Discount  Order_Quantity  \
# Ord_id
# Ord_1      Prod_1     SHP_1    Cust_1    261.54      0.04               6
# Ord_10     Prod_3    SHP_13   Cust_10     80.61      0.02              15
# Ord_100    Prod_8   SHP_138   Cust_58    121.12      0.10               3
# Ord_1000   Prod_6  SHP_1384  Cust_373    334.71      0.01              25
# Ord_1001   Prod_5  SHP_1385  Cust_374   1981.26      0.07              49
# ...           ...       ...       ...       ...       ...             ...
# Ord_997   Prod_14  SHP_1379  Cust_365  28761.52      0.04               8
# Ord_998    Prod_5  SHP_1382  Cust_372   2149.37      0.03              42
# Ord_998    Prod_8  SHP_1380  Cust_372    750.66      0.00              33
# Ord_998    Prod_8  SHP_1381  Cust_372    254.32      0.01               8
# Ord_999   Prod_15  SHP_1383  Cust_361   5661.08      0.00              33
#
#            Profit  Shipping_Cost  Product_Base_Margin
# Ord_id
# ...

# %%
# merging data frames
ship_df=pd.read_csv('https://raw.githubusercontent.com/vviteswar123/ML_FDP_VVIT_2019/master/global_sales_data/shipping_dimen.csv')
prod_df=pd.read_csv('https://raw.githubusercontent.com/vviteswar123/ML_FDP_VVIT_2019/master/global_sales_data/prod_dimen.csv')
order_df=pd.read_csv('https://raw.githubusercontent.com/vviteswar123/ML_FDP_VVIT_2019/master/global_sales_data/orders_dimen.csv')
cust_df=pd.read_csv('https://raw.githubusercontent.com/vviteswar123/ML_FDP_VVIT_2019/master/global_sales_data/cust_dimen.csv')

# %%
ship_df
# Out:
#       Order_ID       Ship_Mode   Ship_Date   Ship_id
# 0            3     REGULAR AIR  20-10-2010     SHP_1
# 1          293  DELIVERY TRUCK  02-10-2012     SHP_2
# 2          293     REGULAR AIR  03-10-2012     SHP_3
# 3          483     REGULAR AIR  12-07-2011     SHP_4
# 4          515     REGULAR AIR  30-08-2010     SHP_5
# ...        ...             ...         ...       ...
# 7696     55558  DELIVERY TRUCK  09-08-2010  SHP_7697
# 7697     55558     REGULAR AIR  11-08-2010  SHP_7698
# 7698     56550     EXPRESS AIR  10-04-2011  SHP_7699
# 7699     56550     REGULAR AIR  09-04-2011  SHP_7700
# 7700     56581     EXPRESS AIR  11-02-2009  SHP_7701
#
# [7701 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
ship_df.columns
# Out:
# Index(['Order_ID', 'Ship_Mode', 'Ship_Date', 'Ship_id'], dtype='object')

# %%
d1=pd.merge(data,ship_df,on='Ship_id')
d1
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Order_ID  \
# 0                 23   -30.51           3.60                 0.56     36262
# ...

# %%
d1.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Order_ID', 'Ship_Mode', 'Ship_Date'],
#       dtype='object')

# %%
cust_df.columns
# Out:
# Index(['Customer_Name', 'Province', 'Region', 'Customer_Segment', 'Cust_id'], dtype='object')

# %%
d2=pd.merge(d1,cust_df,on='Cust_id')
d2
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Order_ID  \
# 0                 23   -30.51           3.60                 0.56     36262
# ...

# %%
d2.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Order_ID', 'Ship_Mode', 'Ship_Date', 'Customer_Name', 'Province',
#        'Region', 'Customer_Segment'],
#       dtype='object')

# %%
order_df.columns
# Out:
# Index(['Order_ID', 'Order_Date', 'Order_Priority', 'Ord_id'], dtype='object')

# %%
d3=pd.merge(d2,order_df,on='Ord_id')
d3
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 2     Ord_5446   Prod_6  SHP_7608  Cust_1818   164.0200      0.03
# 3     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 4     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8395  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8396  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8397  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  Order_ID_x  \
# 0                 23   -30.51           3.60                 0.56       36262
# ...

# %%
d3.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Order_ID_x', 'Ship_Mode', 'Ship_Date', 'Customer_Name', 'Province',
#        'Region', 'Customer_Segment', 'Order_ID_y', 'Order_Date',
#        'Order_Priority'],
#       dtype='object')

# %%
prod_df.columns
# Out:
# Index(['Product_Category', 'Product_Sub_Category', 'Prod_id'], dtype='object')

# %%
master_df=pd.merge(d3,prod_df,on='Prod_id')
master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# ...        ...      ...       ...        ...       ...       ...
# 8394  Ord_5467  Prod_14  SHP_7639  Cust_1803   5964.19      0.10
# 8395   Ord_825  Prod_14  SHP_1132   Cust_247  27663.92      0.05
# 8396  Ord_5368  Prod_14  SHP_7497  Cust_1795  17279.62      0.04
# 8397  Ord_1765  Prod_14  SHP_2446   Cust_595  14647.26      0.07
# 8398  Ord_3610  Prod_14  SHP_4998  Cust_1266   1759.65      0.06
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin  ...  \
# 0                 23   -30.51           3.60                 0.56  ...
# ...

# %%
master_df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Order_ID_x', 'Ship_Mode', 'Ship_Date', 'Customer_Name', 'Province',
#        'Region', 'Customer_Segment', 'Order_ID_y', 'Order_Date',
#        'Order_Priority', 'Product_Category', 'Product_Sub_Category'],
#       dtype='object')

# %%
master_df.Customer_Segment.value_counts()
# Out:
# CORPORATE         3076
# HOME OFFICE       2032
# CONSUMER          1649
# SMALL BUSINESS    1642
# Name: Customer_Segment, dtype: int64

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8399 entries, 0 to 8398
# Data columns (total 22 columns):
# Ord_id                  8399 non-null object
# Prod_id                 8399 non-null object
# Ship_id                 8399 non-null object
# Cust_id                 8399 non-null object
# Sales                   8399 non-null float64
# Discount                8399 non-null float64
# Order_Quantity          8399 non-null int64
# Profit                  8399 non-null float64
# Shipping_Cost           8399 non-null float64
# Product_Base_Margin     8399 non-null float64
# Order_ID_x              8399 non-null int64
# Ship_Mode               8399 non-null object
# Ship_Date               8399 non-null object
# Customer_Name           8399 non-null object
# Province                8399 non-null object
# Region                  8399 non-null object
# Customer_Segment        8399 non-null object
# Order_ID_y              8399 non-null int64
# ...

# %%
master_df.groupby('Customer_Segment').Sales.sum()
# Out:
# Customer_Segment
# CONSUMER          3.063611e+06
# CORPORATE         5.498905e+06
# HOME OFFICE       3.564764e+06
# SMALL BUSINESS    2.788321e+06
# Name: Sales, dtype: float64

# %%
master_df.groupby(['Product_Category','Product_Sub_Category']).Sales.sum()
# Out:
# Product_Category  Product_Sub_Category
# FURNITURE         BOOKCASES                          822652.040
#                   CHAIRS & CHAIRMATS                1761836.550
#                   OFFICE FURNISHINGS                 698093.810
#                   TABLES                            1896008.142
# OFFICE SUPPLIES   APPLIANCES                         736991.540
#                   BINDERS AND BINDER ACCESSORIES    1022957.590
#                   ENVELOPES                          174085.800
#                   LABELS                              38981.550
#                   PAPER                              446452.860
#                   PENS & ART SUPPLIES                167107.220
#                   RUBBER BANDS                        15006.630
#                   SCISSORS, RULERS AND TRIMMERS       80996.310
#                   STORAGE & ORGANIZATION            1070182.600
# TECHNOLOGY        COMPUTER PERIPHERALS               795875.940
# ...

# %%
master_df.groupby('Customer_Segment').sum()
# Out:
#                          Sales  Discount  Order_Quantity     Profit  \
# Customer_Segment
# CONSUMER          3.063611e+06     82.29           41760  287959.94
# CORPORATE         5.498905e+06    153.31           78517  599746.00
# HOME OFFICE       3.564764e+06    100.47           52807  318354.03
# SMALL BUSINESS    2.788321e+06     81.12           41693  315708.01
#
#                   Shipping_Cost  Product_Base_Margin  Order_ID_x  Order_ID_y
# Customer_Segment
# CONSUMER               21477.81           845.775185    48894995    48894995
# CORPORATE              39061.85          1577.315290    90824959    90824959
# HOME OFFICE            25952.21          1043.635185    61422595    61422595
# SMALL BUSINESS         21339.17           837.872672    50534996    50534996

# %%
master_df.groupby('Customer_Segment').Profit.sum()
# Out:
# Customer_Segment
# CONSUMER          287959.94
# CORPORATE         599746.00
# HOME OFFICE       318354.03
# SMALL BUSINESS    315708.01
# Name: Profit, dtype: float64

# %%
master_df.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_2978  Prod_16  SHP_4112  Cust_1088  305.05      0.04              27
# 2  Ord_5484  Prod_16  SHP_7663  Cust_1820  322.82      0.05              35
# 3  Ord_3730  Prod_16  SHP_5175  Cust_1314  459.08      0.04              34
# 4  Ord_4143  Prod_16  SHP_5771  Cust_1417  207.21      0.06              24
#
#    Profit  Shipping_Cost  Product_Base_Margin  ...   Ship_Date  \
# 0  -30.51           3.60                 0.56  ...  28-07-2010
# 1   23.12           3.37                 0.57  ...  26-02-2011
# 2  -17.58           3.98                 0.56  ...  03-03-2012
# 3   61.57           3.14                 0.60  ...  09-12-2009
# 4  -78.64           6.14                 0.59  ...  10-10-2009
#
#          Customer_Name       Province    Region Customer_Segment Order_ID_y  \
# ...

# %%
# Graphs

# %%
import matplotlib.pyplot as plt
plt.hist(master_df.Discount)
# Out:
# (array([2.327e+03, 1.549e+03, 2.230e+03, 1.543e+03, 7.460e+02, 0.000e+00,
#         2.000e+00, 0.000e+00, 1.000e+00, 1.000e+00]),
#  array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#         0.225, 0.25 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(master_df.Discount,bins=5)
# Out:
# (array([3.876e+03, 3.773e+03, 7.460e+02, 2.000e+00, 2.000e+00]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(master_df.Sales,bins=5)
# Out:
# (array([8.305e+03, 9.100e+01, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([2.2400000e+00, 1.7814002e+04, 3.5625764e+04, 5.3437526e+04,
#         7.1249288e+04, 8.9061050e+04]),
#  <a list of 5 Patch objects>)

# %%
plt.boxplot(master_df.Discount)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1652ebb7f08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1652ebbfac8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1652ebb76c8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1652ebcdfc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1652ee268c8>],
#  'means': []}

# %%
q1=np.quantile(master_df.Discount,0.25)
q2=np.quantile(master_df.Discount,0.5)
q3=np.quantile(master_df.Discount,0.75)
IQR=1.5*(q3-q1)
# the values greater than q3+iqr or the values less than q1-iqr are outliers (q1-iqr,q3+iqr)
(q1-IQR,q3+IQR)
# Out:
# (-0.06999999999999999, 0.16999999999999998)

# %%
plt.scatter(master_df.Sales,master_df.Profit)

# %%
master_df.Profit.hist()

# %%
master_df.Discount.hist()

# %%
i=master_df.Customer_Segment.value_counts().index
v=master_df.Customer_Segment.value_counts()
plt.bar(i,v)
# Out:
# <BarContainer object of 4 artists>

# %%
import seaborn as sns
sns.distplot(master_df.Discount,hist=False,rug=True)

# %%
sns.countplot(master_df.Product_Category)

# %%
sns.countplot(master_df.Product_Sub_Category)

# %%
sns.pairplot(master_df)

# %%
master_df.corr()
# Out:
#                         Sales  Discount  Order_Quantity    Profit  \
# Sales                1.000000 -0.019686        0.220582  0.581960
# Discount            -0.019686  1.000000       -0.009649 -0.037128
# Order_Quantity       0.220582 -0.009649        1.000000  0.194655
# Profit               0.581960 -0.037128        0.194655  1.000000
# Shipping_Cost        0.434578 -0.001956       -0.011457 -0.021362
# Product_Base_Margin  0.155794  0.004062        0.007817 -0.112124
# Order_ID_x          -0.007792 -0.003213        0.010953 -0.006820
# Order_ID_y          -0.007792 -0.003213        0.010953 -0.006820
#
#                      Shipping_Cost  Product_Base_Margin  Order_ID_x  \
# Sales                     0.434578             0.155794   -0.007792
# Discount                 -0.001956             0.004062   -0.003213
# Order_Quantity           -0.011457             0.007817    0.010953
# Profit                   -0.021362            -0.112124   -0.006820
# ...

# %%
sns.jointplot(master_df.Discount,master_df.Sales)

# %%
sns.jointplot('Discount','Sales',master_df)

# %%
a=np.linspace(20,45,10)
plt.subplot(2,2,1)
plt.plot(a,a**2,'-r')
plt.subplot(2,2,2)
plt.plot(a,a*3+5,'^g')
plt.subplot(2,2,3)
plt.plot(a,a**3+3*a,'*b')
plt.subplot(2,2,4)
plt.plot(a,a*4)

# %%
num_cols=master_df.columns[master_df.dtypes!=object]

# %%
num_cols
# Out:
# Index(['Sales', 'Discount', 'Order_Quantity', 'Profit', 'Shipping_Cost',
#        'Product_Base_Margin', 'Order_ID_x', 'Order_ID_y'],
#       dtype='object')

# %%
plt.figure(figsize=(20,40))
for i in range(len(num_cols)):
    plt.subplot(4,2,i+1)
    plt.hist(master_df[num_cols[i]])

# %% [markdown]
# # other plt functions
# plt.title()
# plt.xlim()
# plt.ylim()
# plt.xticks()
# plt.xlabel()
